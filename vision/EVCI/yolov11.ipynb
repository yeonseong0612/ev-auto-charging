# %%
#coco8 test
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("models/yolo11n.pt")

# Train the model on COCO8
results = model.train(data="coco8.yaml", epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.197 🚀 Python-3.8.20 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=models/yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/mnt/d/EVCI/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/mnt/d/EVCI/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/mnt/d/EVCI/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 276.6KB/s 1.6s 1.6s<0.1s
# Unzipping /mnt/d/EVCI/datasets/coco8.zip to /mnt/d/EVCI/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 460.7files/s 0.1s
# Dataset download success ✅ (2.5s), saved to /mnt/d/EVCI/datasets
# Bad pipe message: %s [b'"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium"']
# Bad pipe message: %s [b'="139"\r\nsec-ch-ua-mobile: ?0\r\nsec-ch-ua-platform: "Windows']
# Bad pipe message: %s [b'\nUpgrade-Insecure-Requests: 1\r\nUs', b'-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.']
# Bad pipe message: %s [b'0.0 Safari/537.36\r\nAccept: text/html,applicatio']
# Bad pipe message: %s [b'xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q', b'.7\r\nSec-Fetch-Site: none\r\nSec-Fetch-Mode: navigate\r\nSec-Fetc']
# Bad pipe message: %s [b'ol: max-age=0\r\nsec-ch-ua: "Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"\r\nsec-ch-ua-mobile: ?0\r\n']
# Bad pipe message: %s [b'c-ch-ua-platform: "Windows"\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) A', b'leWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36\r\nAccept: text/html,application/xhtml+xml,app']
# Bad pipe message: %s [b'cation/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nSec-Fet', b'-Site: none\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Dest: document\r\nAccept-Encodi']
# Downloading https://ultralytics.com/assets/Arial.ttf to '/tmp/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 234.8KB/s 3.2s 3.1s<0.3s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 831.7KB/s 6.6s6s<0.0s1s30.8s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 11.7±4.9 ms, read: 4.6±4.1 MB/s, size: 50.0 KB)
# train: Scanning /mnt/d/EVCI/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 154.2it/s 0.0s
# train: New cache created: /mnt/d/EVCI/datasets/coco8/labels/train.cache
# val: Fast image access ✅ (ping: 1.3±0.2 ms, read: 20.6±10.0 MB/s, size: 54.0 KB)
# val: Scanning /mnt/d/EVCI/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 476.1it/s 0.0s
# val: New cache created: /mnt/d/EVCI/datasets/coco8/labels/val.cache
# Plotting labels to /mnt/d/EVCI/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /mnt/d/EVCI/runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10     0.664G      1.104       2.79      1.388         13        640: 100% ━━━━━━━━━━━━ 1/1 0.2it/s 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.7it/s 1.5s
#                    all          4         17      0.587       0.85       0.85      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10     0.688G      1.133      1.668      1.384         13        640: 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 12.2it/s 0.1s
#                    all          4         17      0.601       0.85       0.85      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10     0.688G       1.07      2.296      1.511         13        640: 100% ━━━━━━━━━━━━ 1/1 12.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 28.0it/s 0.0s
#                    all          4         17      0.604       0.85      0.853       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10     0.688G      1.254      1.924      1.678         13        640: 100% ━━━━━━━━━━━━ 1/1 11.4it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 27.0it/s 0.0s
#                    all          4         17      0.618       0.85      0.854      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10     0.689G     0.9483      2.341      1.381         13        640: 100% ━━━━━━━━━━━━ 1/1 8.9it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.3it/s 0.0s
#                    all          4         17      0.625       0.85      0.855      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10     0.689G      0.999      1.943      1.423         13        640: 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.9it/s 0.0s
#                    all          4         17      0.627       0.85      0.857      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10     0.705G      1.211      2.243      1.484         13        640: 100% ━━━━━━━━━━━━ 1/1 9.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.0it/s 0.0s
#                    all          4         17      0.628       0.85      0.858      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10     0.705G     0.7546      1.789      1.194         13        640: 100% ━━━━━━━━━━━━ 1/1 9.8it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.4it/s 0.0s
#                    all          4         17      0.624       0.85      0.861      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10     0.705G     0.9709      1.525      1.366         13        640: 100% ━━━━━━━━━━━━ 1/1 10.8it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.8it/s 0.0s
#                    all          4         17       0.62       0.85      0.858      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10     0.705G       1.14      1.522      1.401         13        640: 100% ━━━━━━━━━━━━ 1/1 9.4it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.7it/s 0.0s
#                    all          4         17      0.626       0.85      0.859      0.626
#
# 10 epochs completed in 0.003 hours.
# Optimizer stripped from /mnt/d/EVCI/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /mnt/d/EVCI/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /mnt/d/EVCI/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.197 🚀 Python-3.8.20 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 20.1it/s 0.0s
#                    all          4         17      0.616       0.85      0.854      0.653
#                 person          3         10      0.599        0.6      0.618      0.295
#                    dog          1          1      0.553          1      0.995      0.796
#                  horse          1          2      0.713          1      0.995      0.674
#               elephant          1          2      0.379        0.5      0.526       0.26
#               umbrella          1          1      0.582          1      0.995      0.995
#           potted plant          1          1       0.87          1      0.995      0.895
# Speed: 0.3ms preprocess, 4.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /mnt/d/EVCI/runs/detect/train

# %%
from ultralytics import settings

# View all settings
print(settings)

# Return a specific setting
settings["tensorboard"]=True
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/mnt/e/ev-auto-charging/vision/EVCI/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "7fb21f8fbc8a46795a2959ee47c9acb4357ab78ea7b186fa80cb323ccacaa5cd",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }
